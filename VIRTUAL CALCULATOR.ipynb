# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\saxen\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\saxen\anaconda3\lib\site-packages (from opencv-python) (1.23.5)

# %%
pip install cvzone
# Out:
# Requirement already satisfied: cvzone in c:\users\saxen\anaconda3\lib\site-packages (1.5.6)
# Requirement already satisfied: numpy in c:\users\saxen\anaconda3\lib\site-packages (from cvzone) (1.23.5)
# Requirement already satisfied: opencv-python in c:\users\saxen\anaconda3\lib\site-packages (from cvzone) (4.8.0.74)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\saxen\appdata\roaming\python\python310\site-packages (0.10.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\saxen\appdata\roaming\python\python310\site-packages (from mediapipe) (4.8.0.74)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\saxen\appdata\roaming\python\python310\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: numpy in c:\users\saxen\anaconda3\lib\site-packages (from mediapipe) (1.23.5)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\saxen\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: absl-py in c:\users\saxen\appdata\roaming\python\python310\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\saxen\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\users\saxen\anaconda3\lib\site-packages (from mediapipe) (3.7.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\saxen\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\saxen\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saxen\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pycparser in c:\users\saxen\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\saxen\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
# Hand detector-to detect our hands and to see if we have clicked on button or not
from cvzone.HandTrackingModule import HandDetector
class Button:
    def __init__(self, pos, width, height, value):
        self.pos = pos
        self.width = width
        self.height = height
        self.value = value

    def draw(self, img):
        cv2.rectangle(img, self.pos, (self.pos[0] + self.width, self.pos[1] + self.height),
                      (225, 225, 225), cv2.FILLED)
        cv2.rectangle(img, self.pos, (self.pos[0] + self.width, self.pos[1] + self.height),
                      (50, 50, 50), 3)
        cv2.putText(img, self.value, (self.pos[0] + 40, self.pos[1] + 60), cv2.FONT_HERSHEY_PLAIN,
                    2, (50, 50, 50), 2)
    def checkClick(self, x, y):
        if self.pos[0] < x < self.pos[0] + self.width and \
                self.pos[1] < y < self.pos[1] + self.height:
            cv2.rectangle(img, (self.pos[0] + 3, self.pos[1] + 3),
                          (self.pos[0] + self.width - 3, self.pos[1] + self.height - 3),
                          (255, 255, 255), cv2.FILLED)
            cv2.putText(img, self.value, (self.pos[0] + 25, self.pos[1] + 80), cv2.FONT_HERSHEY_PLAIN,
                        5, (0, 0, 0), 5)
            return True
        else:
            return False

# %%
# Adding webcam
cap = cv2.VideoCapture(0) #web cam no
cap.set(3,1280)# is used to set the width of the video capture object (cap) to 1280 pixels.
#property index 3 corresponds to the property CV_CAP_PROP_FRAME_WIDTH, which is used in older versions of OpenCV
cap.set(4,720)
#property index 4 corresponds to CV_CAP_PROP_FRAME_HEIGHT (or cv2.CAP_PROP_FRAME_HEIGHT in recent versions of OpenCV)
detector=HandDetector(detectionCon=0.8,maxHands=1) #if it is 80 per confident that it is hand than only it will detect hence detection confidence=0.8
#creating button
# Buttons
buttonListValues = [['7', '8', '9', '*'],
                    ['4', '5', '6', '-'],
                    ['1', '2', '3', '+'],
                    ['0', '/', '.', '=']]
buttonList = []
for x in range(4):
    for y in range(4):
        xpos = x * 100 + 800
        ypos = y * 100 + 150

        buttonList.append(Button((xpos, ypos), 100, 100, buttonListValues[y][x]))
#variables
myEquation = ''
delayCounter = 0

# %%
#loop
while True:
    success, img = cap.read()
    img = cv2.flip(img, 1)
    hands, img = detector.findHands(img)

    # Draw All
    cv2.rectangle(img, (800, 50), (800 + 400, 70 + 100),
                  (225, 225, 225), cv2.FILLED)

    cv2.rectangle(img, (800, 50), (800 + 400, 70 + 100),
                  (50, 50, 50), 3)
    for button in buttonList:
        button.draw(img)
    if hands:
        lmList = hands[0]['lmList']
        length, _, img = detector.findDistance((lmList[8][0], lmList[8][1]), (lmList[12][0], lmList[12][1]), img)
        print(length)
        x, y = lmList[8][0], lmList[8][1]
        if length < 50 and delayCounter == 0:
            for i, button in enumerate(buttonList):
                if button.checkClick(x, y):
                    myValue = buttonListValues[int(i % 4)][int(i / 4)]  # get correct number
                    if myValue == '=':
                        myEquation = str(eval(myEquation))
                    else:
                        myEquation += myValue
                    delayCounter = 1
    # avoid delay counter
    # to avoid multiple clicks
    if delayCounter != 0:
        delayCounter += 1
        if delayCounter > 10:
            delayCounter = 0
    cv2.putText(img, myEquation, (810, 130), cv2.FONT_HERSHEY_PLAIN,
                3, (0, 0, 0), 3)

    key = cv2.waitKey(1)
    cv2.imshow("Image", img)
    if key == ord('c'):
        myEquation = ''
# Out:
# 38.8329756778952
# 25.079872407968907
# 23.0
# 22.0
# 21.095023109728988
# 22.090722034374522
# 20.396078054371138
# 20.615528128088304
# 20.396078054371138
# 18.24828759089466
# 19.4164878389476
# 19.4164878389476
# 20.223748416156685
# 19.4164878389476
# 19.235384061671343
# 18.027756377319946
# 18.027756377319946
# 19.4164878389476
# 19.4164878389476
# 19.235384061671343
# 18.24828759089466
# 19.1049731745428
# 19.1049731745428
# 19.1049731745428
# 18.110770276274835
# 17.11724276862369
# 18.24828759089466
# 18.24828759089466
# 19.026297590440446
# 18.110770276274835
# 19.4164878389476
# 20.396078054371138
# 21.095023109728988
# 19.4164878389476
# 18.439088914585774
# 18.0
# 19.1049731745428
# 18.027756377319946
# 17.11724276862369
# 18.110770276274835
# 19.026297590440446
# 16.1245154965971
# 17.11724276862369
# 18.110770276274835
# 15.132745950421556
# 18.027756377319946
# 17.26267650163207
# 15.132745950421556
# 18.110770276274835
# 19.026297590440446
# 18.681541692269406
# 19.026297590440446
# 18.0
# 17.11724276862369
# 18.24828759089466
# 15.132745950421556
# 16.76305461424021
# 18.027756377319946
# 14.035668847618199
# 16.492422502470642
# 14.0
# 15.0
# 15.033296378372908
# 13.92838827718412
# 15.297058540778355
# 15.297058540778355
# 15.132745950421556
# 17.26267650163207
# 15.132745950421556
# 15.033296378372908
# 14.560219778561036
# 13.152946437965905
# 13.341664064126334
# 14.035668847618199
# 14.560219778561036
# 11.180339887498949
# 14.317821063276353
# 8.54400374531753
# 13.92838827718412
# 7.280109889280518
# 13.152946437965905
# 15.0
# 16.278820596099706
# 12.649110640673518
# 14.866068747318506
# 13.038404810405298
# 13.038404810405298
# 13.341664064126334
# 13.0
# 14.142135623730951
# 13.341664064126334
# 14.142135623730951
# 14.560219778561036
# 13.152946437965905
# 15.132745950421556
# 14.142135623730951
# 13.152946437965905
# 13.601470508735444
# 2.0
# 13.0
# 13.601470508735444
# 12.041594578792296
# 13.341664064126334
# 13.341664064126334
# 17.029386365926403
# 12.041594578792296
# 14.317821063276353
# 15.033296378372908
# 13.601470508735444
# 12.36931687685298
# 19.6468827043885
# 20.223748416156685
# 21.095023109728988
# 21.213203435596427
# 21.213203435596427
# 22.360679774997898
# 20.223748416156685
# 20.396078054371138
# 24.515301344262525
# 22.360679774997898
# 21.587033144922902
